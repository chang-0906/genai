# %% [markdown]
# # G4F

# %% [markdown]
# ### Gemini

# %%
from openai import OpenAI

client = OpenAI(
    api_key="g4f_u_mn9y36_f4aa688fd5f07e9500b5bd4faae3ca49884f46f5adeeddc0_e9527913",
    base_url="https://g4f.space/api/gemini",
)

response = client.chat.completions.create(
    model="models/gemini-2.5-flash",
    messages=[
        {"role": "user", "content": "請用繁體中文簡短介紹你自己。"}
    ],
    temperature=0.7,
)

print(response.choices[0].message.content)
# Out:
# 您好！我是由 Google 訓練的大型語言模型。

# %% [markdown]
# ### Pollinations - openai

# %%
from openai import OpenAI

client = OpenAI(
    api_key="g4f_u_mn9y36_f4aa688fd5f07e9500b5bd4faae3ca49884f46f5adeeddc0_e9527913",
    base_url="https://g4f.space/api/pollinations",
)

response = client.chat.completions.create(
    model="openai",
    messages=[
        {"role": "user", "content": "請用繁體中文簡短介紹你自己。"}
    ],
    temperature=0.7,
)

print(response.choices[0].message.content)
# Out:
# 你好，我是由 OpenAI 訓練的語言模型（AI 助手）。我可以用繁體中文回答問題、撰寫或潤飾文字、翻譯、整理摘要、協助程式碼與學習等任務。我的知識截至 2024 年 6 月，無法存取即時網路或個人隱私資料，也沒有自我意識或個人經驗。需要幫忙的話請告訴我你想做什麼。

# %% [markdown]
# ### Perplexity

# %%
from openai import OpenAI

client = OpenAI(
    api_key="g4f_u_mn9y36_f4aa688fd5f07e9500b5bd4faae3ca49884f46f5adeeddc0_e9527913",
    base_url="https://g4f.space/api/perplexity",
)

response = client.chat.completions.create(
    model="auto",
    messages=[
        {"role": "user", "content": "請用繁體中文簡短介紹你自己。"}
    ],
    temperature=0.7,
)

print(response.choices[0].message.content)
# Out:
# 我是 Perplexity，一個以使用者需求為中心的人工智慧助手。我專長在寫作、創意、概念解釋、摘要與創新腦力激盪，幫你快速得到清晰、實用的答案與產出。若你有任何問題或需要協助，告訴我就好！
